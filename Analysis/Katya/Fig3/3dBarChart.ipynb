# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
# %matplotlib inline

# %%
chunks = ['S'+str(i) for i in range(1,13)]
data = {}
clean_data = {}

for f in os.listdir('/home/katya/start/HIS3InterspeciesEpistasis/Data/'):
    if 'csv' in f:
        data[f[:-16]] = pd.DataFrame.from_csv('/home/katya/start/HIS3InterspeciesEpistasis/Data/' + f, sep = '\t')
        clean_data[f[:-16]] = data[f[:-16]][(data[f[:-16]].nonsense == 0) & (data[f[:-16]].middle == 1) & (data[f[:-16]].nat_lib == 1)]
        clean_data[f[:-16]] = clean_data[f[:-16]].sample(1000)

# %%
clean_data['S7'].dist_Scer
# Out:
# aa_seq
# IHALAKHSGWSLIVECIGDLVVDDHHSSED    4
# FHALAKHGGWSLIVECIGDLHVDDHHSIED    5
# YNALAKHGGWSLIVECIGDLFVDDHHTTED    5
# YHALAKHAGWSLIVECIGDLYIDDHHSTED    4
# INALAKHSGWSLIVECIGDLFIDDHHTTED    2
# LTALAKHAGWSLIVECIGDLYIDDHHSSED    6
# YNALAKHGGWSLIVECIGDLVVDDHHSVED    7
# LNALAKHGGWSLIVECIGDLFIDDHHTIED    5
# LTALAKHAGWSLIVECIGDLVVDDHHSLED    7
# INALAKHSGWSLIVECIGDLYIDDHHSVED    4
# YHALAKHAGWSLIVECIGDLHIDDHHSIED    4
# YHALAKHSGWSLIVECIGDLHIDDHHSVED    3
# YHALAKHSGWSLIVECIGDLHIDDHHSAED    3
# INALAKHGGWSLIVECIGDLDVDDHHSAED    6
# IHALAKHGGWSLIVECIGDLDIDDHHSTED    3
# YNALAKHGGWSLIVECIGDLDIDDHHSSED    6
# YHALAKHGGWSLIVECIGDLHIDDHHTTED    2
# ITALAKHSGWSLIVECIGDLVVDDHHTVED    4
# YTALAKHSGWSLIVECIGDLFIDDHHSLED    5
# INALAKHAGWSLIVECIGDLDIDDHHTAED    4
# FHALAKHAGWSLIVECIGDLHIDDHHTLED    3
# YTALAKHAGWSLIVECIGDLDIDDHHTVED    5
# YTALAKHAGWSLIVECIGDLFIDDHHSLED    6
# FNALAKHAGWSLIVECIGDLVVDDHHTSED    6
# FTALAKHAGWSLIVECIGDLYVDDHHTLED    6
# YNALAKHAGWSLIVECIGDLVVDDHHTIED    6
# YHALAKHSGWSLIVECIGDLFVDDHHSIED    5
# FNALAKHSGWSLIVECIGDLVIDDHHTSED    4
# LTALAKHAGWSLIVECIGDLDIDDHHTLED    5
# FNALAKHGGWSLIVECIGDLFIDDHHTTED    4
#                                  ..
# IHALAKHSGWSLIVECIGDLVVDDHHTSED    3
# ITALAKHGGWSLIVECIGDLYIDDHHTIED    4
# FHALAKHGGWSLIVECIGDLYVDDHHSSED    6
# ITALAKHAGWSLIVECIGDLDIDDHHTSED    4
# YNALAKHAGWSLIVECIGDLFIDDHHTVED    5
# FNALAKHAGWSLIVECIGDLHVDDHHSVED    6
# INALAKHSGWSLIVECIGDLYIDDHHTVED    3
# INALAKHGGWSLIVECIGDLFVDDHHSVED    6
# IHALAKHAGWSLIVECIGDLYVDDHHSTED    4
# LHALAKHAGWSLIVECIGDLYIDDHHTAED    4
# INALAKHAGWSLIVECIGDLFVDDHHTTED    4
# YHALAKHAGWSLIVECIGDLHVDDHHSVED    5
# FNALAKHSGWSLIVECIGDLVVDDHHTSED    5
# IHALAKHSGWSLIVECIGDLFVDDHHSVED    4
# IHALAKHGGWSLIVECIGDLDVDDHHTSED    4
# FNALAKHSGWSLIVECIGDLVIDDHHSAED    5
# LNALAKHAGWSLIVECIGDLFVDDHHTLED    6
# YNALAKHSGWSLIVECIGDLVIDDHHSTED    4
# YNALAKHGGWSLIVECIGDLFIDDHHTSED    5
# FTALAKHAGWSLIVECIGDLVVDDHHSVED    7
# FHALAKHGGWSLIVECIGDLFVDDHHTVED    5
# FTALAKHSGWSLIVECIGDLYVDDHHSAED    6
# ITALAKHAGWSLIVECIGDLHIDDHHSLED    4
# YTALAKHSGWSLIVECIGDLHIDDHHSSED    4
# YTALAKHSGWSLIVECIGDLYVDDHHTVED    5
# YTALAKHSGWSLIVECIGDLYIDDHHTTED    3
# LHALAKHGGWSLIVECIGDLDVDDHHTLED    5
# LTALAKHSGWSLIVECIGDLFVDDHHTSED    5
# YNALAKHSGWSLIVECIGDLFVDDHHTSED    5
# YHALAKHGGWSLIVECIGDLDVDDHHSIED    6
# Name: dist_Scer, dtype: int64

# %%
clean_data['S7'].s[clean_data['S7'].dist_Scer<=3]
# Out:
# aa_seq
# INALAKHSGWSLIVECIGDLFIDDHHTTED    0.454213
# YHALAKHSGWSLIVECIGDLHIDDHHSVED    0.254386
# YHALAKHSGWSLIVECIGDLHIDDHHSAED    0.000000
# IHALAKHGGWSLIVECIGDLDIDDHHSTED    0.513899
# YHALAKHGGWSLIVECIGDLHIDDHHTTED    0.000000
# FHALAKHAGWSLIVECIGDLHIDDHHTLED    0.449695
# LHALAKHGGWSLIVECIGDLYIDDHHTTED    0.431332
# INALAKHSGWSLIVECIGDLHIDDHHTTED    0.446399
# YHALAKHSGWSLIVECIGDLHVDDHHTSED    0.064842
# IHALAKHSGWSLIVECIGDLHVDDHHSLED    0.456324
# YHALAKHSGWSLIVECIGDLHIDDHHSIED    0.211572
# YTALAKHSGWSLIVECIGDLFIDDHHTTED    0.128560
# IHALAKHAGWSLIVECIGDLHIDDHHSAED    0.454357
# YHALAKHGGWSLIVECIGDLHIDDHHSTED    0.000000
# FNALAKHSGWSLIVECIGDLHIDDHHTVED    0.450082
# IHALAKHSGWSLIVECIGDLVVDDHHTAED    0.462691
# IHALAKHAGWSLIVECIGDLDIDDHHTSED    0.415071
# YHALAKHSGWSLIVECIGDLFIDDHHTIED    0.277041
# LHALAKHSGWSLIVECIGDLHIDDHHTVED    0.451593
# INALAKHSGWSLIVECIGDLHIDDHHSSED    0.458518
# YNALAKHSGWSLIVECIGDLHVDDHHTTED    0.148169
# LHALAKHAGWSLIVECIGDLHIDDHHSTED    0.442535
# INALAKHAGWSLIVECIGDLHIDDHHTSED    0.461686
# INALAKHSGWSLIVECIGDLDIDDHHSTED    0.446077
# LHALAKHSGWSLIVECIGDLDIDDHHTSED    0.459276
# IHALAKHAGWSLIVECIGDLHIDDHHSSED    0.455612
# FHALAKHSGWSLIVECIGDLVVDDHHTTED    0.447957
# IHALAKHSGWSLIVECIGDLYIDDHHSSED    0.450973
# LHALAKHAGWSLIVECIGDLHVDDHHTTED    0.452845
# ITALAKHSGWSLIVECIGDLHVDDHHTLED    0.438359
#                                     ...
# IHALAKHSGWSLIVECIGDLVIDDHHTSED    0.449010
# IHALAKHSGWSLIVECIGDLHVDDHHTIED    0.452116
# IHALAKHSGWSLIVECIGDLHIDDHHSSED    0.456619
# INALAKHSGWSLIVECIGDLHVDDHHTSED    0.458059
# YNALAKHSGWSLIVECIGDLDIDDHHTTED    0.177692
# IHALAKHGGWSLIVECIGDLVIDDHHTVED    0.458949
# IHALAKHSGWSLIVECIGDLHIDDHHTSED    0.459993
# YHALAKHGGWSLIVECIGDLHVDDHHTTED    0.070676
# YHALAKHSGWSLIVECIGDLHIDDHHTAED    0.338993
# IHALAKHAGWSLIVECIGDLHVDDHHTSED    0.458238
# LNALAKHSGWSLIVECIGDLHIDDHHTSED    0.453858
# FHALAKHSGWSLIVECIGDLHVDDHHTTED    0.463222
# LTALAKHAGWSLIVECIGDLHIDDHHTTED    0.454810
# FNALAKHSGWSLIVECIGDLHIDDHHTIED    0.457767
# IHALAKHSGWSLIVECIGDLHIDDHHTTED    0.453711
# FHALAKHGGWSLIVECIGDLHIDDHHTIED    0.457835
# ITALAKHSGWSLIVECIGDLHIDDHHTIED    0.456864
# YHALAKHGGWSLIVECIGDLDIDDHHTTED    0.025745
# LHALAKHAGWSLIVECIGDLHIDDHHTTED    0.451631
# YHALAKHSGWSLIVECIGDLDVDDHHTTED    0.366112
# INALAKHGGWSLIVECIGDLYIDDHHTTED    0.432720
# ITALAKHSGWSLIVECIGDLHVDDHHTTED    0.456647
# IHALAKHGGWSLIVECIGDLYIDDHHTIED    0.448771
# YHALAKHGGWSLIVECIGDLHIDDHHTAED    0.068662
# IHALAKHSGWSLIVECIGDLHVDDHHTLED    0.461312
# IHALAKHSGWSLIVECIGDLVIDDHHSIED    0.439582
# IHALAKHSGWSLIVECIGDLDIDDHHTTED    0.458101
# IHALAKHSGWSLIVECIGDLVVDDHHTSED    0.453451
# INALAKHSGWSLIVECIGDLYIDDHHTVED    0.443645
# YTALAKHSGWSLIVECIGDLYIDDHHTTED    0.170088
# Name: s, dtype: float64

# %%
fig = plt.figure(figsize=[10,8])
ax = fig.add_subplot(111, projection='3d')

# Construct arrays for the anchor positions of the 16 bars.
# Note: np.meshgrid gives arrays in (ny, nx) so we use 'F' to flatten xpos,
# ypos in column-major order. For numpy >= 1.7, we could instead call meshgrid
# with indexing='ij'.


####
angle = np.arange(0, np.pi*2, 0.05)
r = 50

x = r * np.cos(angle)
y = r * np.sin(angle)

idx = np.random.permutation(angle.shape[0])
x = x[idx]
y = y[idx]

angle = np.arctan2(x, y)
order = np.argsort(angle)
x = x[order]
y = y[order]

ax.set_aspect(1.0)
x2 = np.r_[x, x[0]]
y2 = np.r_[y, y[0]]

z2 = np.zeros_like(x2)

dx = 3 * np.ones_like(z2)
dy = dx.copy()
dz = np.random.rand(127)*0

# ax.plot(x2, y2, "r", lw=0.1)
ax.bar3d(x2, y2, z2, dx, dy, dz, color='#00AEE9', edgecolor='white', linewidth=0.1, alpha=.1, zsort='average')

###

r = 45

x = r * np.cos(angle)
y = r * np.sin(angle)

idx = np.random.permutation(angle.shape[0])
x = x[idx]
y = y[idx]

angle = np.arctan2(x, y)
order = np.argsort(angle)
x = x[order]
y = y[order]

ax.set_aspect(1.0)
x2 = np.r_[x, x[0]]
y2 = np.r_[y, y[0]]

z2 = np.zeros_like(x2)

dx = 3 * np.ones_like(z2)
dy = dx.copy()
dz = np.random.rand(127)*0

# ax.plot(x2, y2, "r", lw=0.1)
ax.bar3d(x2, y2, z2, dx, dy, dz, color='#00AEE9', edgecolor='white', linewidth=0.1, alpha=.1, zsort='average')

####

# Get rid of the panes
ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))

# Get rid of the spines
ax.w_xaxis.line.set_color((1.0, 1.0, 1.0, 0.0))
ax.w_yaxis.line.set_color((1.0, 1.0, 1.0, 0.0))
ax.w_zaxis.line.set_color((1.0, 1.0, 1.0, 0.0))

# Get rid of the ticks
ax.set_xticks([]) 
ax.set_yticks([]) 
ax.set_zticks([])


ax.view_init(60, 100)

# %%
xpos
# Out:
# array([ 0.25,  0.25,  0.25,  0.25,  0.25,  0.25,  0.25,  0.25,  0.25,
#         0.25,  0.65,  0.65,  0.65,  0.65,  0.65,  0.65,  0.65,  0.65,
#         0.65,  0.65,  1.05,  1.05,  1.05,  1.05,  1.05,  1.05,  1.05,
#         1.05,  1.05,  1.05,  1.45,  1.45,  1.45,  1.45,  1.45,  1.45,
#         1.45,  1.45,  1.45,  1.45,  1.85,  1.85,  1.85,  1.85,  1.85,
#         1.85,  1.85,  1.85,  1.85,  1.85,  2.25,  2.25,  2.25,  2.25,
#         2.25,  2.25,  2.25,  2.25,  2.25,  2.25,  2.65,  2.65,  2.65,
#         2.65,  2.65,  2.65,  2.65,  2.65,  2.65,  2.65,  3.05,  3.05,
#         3.05,  3.05,  3.05,  3.05,  3.05,  3.05,  3.05,  3.05,  3.45,
#         3.45,  3.45,  3.45,  3.45,  3.45,  3.45,  3.45,  3.45,  3.45,
#         3.85,  3.85,  3.85,  3.85,  3.85,  3.85,  3.85,  3.85,  3.85,  3.85])

# %%
ypos
# Out:
# array([ 0.25,  0.65,  1.05,  1.45,  1.85,  2.25,  2.65,  3.05,  3.45,
#         3.85,  0.25,  0.65,  1.05,  1.45,  1.85,  2.25,  2.65,  3.05,
#         3.45,  3.85,  0.25,  0.65,  1.05,  1.45,  1.85,  2.25,  2.65,
#         3.05,  3.45,  3.85,  0.25,  0.65,  1.05,  1.45,  1.85,  2.25,
#         2.65,  3.05,  3.45,  3.85,  0.25,  0.65,  1.05,  1.45,  1.85,
#         2.25,  2.65,  3.05,  3.45,  3.85,  0.25,  0.65,  1.05,  1.45,
#         1.85,  2.25,  2.65,  3.05,  3.45,  3.85,  0.25,  0.65,  1.05,
#         1.45,  1.85,  2.25,  2.65,  3.05,  3.45,  3.85,  0.25,  0.65,
#         1.05,  1.45,  1.85,  2.25,  2.65,  3.05,  3.45,  3.85,  0.25,
#         0.65,  1.05,  1.45,  1.85,  2.25,  2.65,  3.05,  3.45,  3.85,
#         0.25,  0.65,  1.05,  1.45,  1.85,  2.25,  2.65,  3.05,  3.45,  3.85])

# %% [markdown]
# x = [1,2,3]  #x coordinates of each bar
#
# y = [0,0,0]  #y coordinates of each bar
#
# z = [0,0,0]  #z coordinates of each bar
#
# dx = [0.5, 0.5, 0.5]  #width of each bar
#
# dy = [0.5, 0.5, 0.5]  #depth of each bar
#
# dz = [5, 4, 7]        #height of each bar
