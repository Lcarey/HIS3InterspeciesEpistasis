# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from matplotlib import cm
import os
import distance
# %matplotlib inline
sns.set(rc={'axes.facecolor':'#FFFFFF'})
sns.set_style('whitegrid')
pd.set_option('display.max_columns', 100)

# %%
data = {}
clean_data = {}

for f in os.listdir('/Users/katya/Lab/CRG/Research/HIS3InterspeciesEpistasis/Data/'):
    if 'csv' in f:
        data[f[:-16]] = pd.DataFrame.from_csv('/Users/katya/Lab/CRG/Research/HIS3InterspeciesEpistasis/Data/' + f, sep = '\t')
        clean_data[f[:-16]] = data[f[:-16]][(data[f[:-16]].nonsense == 0) & (data[f[:-16]].middle == 1)]

# %%
columns = list(clean_data['S1'].columns)

# %%
sqs = {}

for chunk in clean_data:
    sqs[chunk] = list(clean_data[chunk].index)

# %%
positions = pd.DataFrame.from_csv('/Users/katya/Lab/CRG/Research/HIS3InterspeciesEpistasis/Data_Small_Tables/positions.csv', sep = '\t')

# %%
positions
# Out:
#                                                           S1  \
# wt1                                               EALGAVRGVK
# positions  [140, 141, 142, 143, 144, 145, 146, 147, 148, ...
# len1                                                      10
# len2                                                      10
# start1                                                   140
# end1                                                     149
# wt2                                               EALSRAVVDL
# start2                                                   160
# end2                                                     169
#
#                                                           S2  \
# wt1                                                SNRPYAVVE
# positions  [170, 171, 172, 173, 174, 175, 176, 177, 178, ...
# len1                                                       9
# len2                                                       9
# start1                                                   170
# end1                                                     178
# wt2                                                LSCEMIPHF
# start2                                                   189
# end2                                                     197
#
#                                                           S3  \
# wt1                                               LGLQREKVGD
# positions  [179, 180, 181, 182, 183, 184, 185, 186, 187, ...
# len1                                                      10
# len2                                                       7
# start1                                                   179
# end1                                                     188
# wt2                                                  LESFAEA
# start2                                                   198
# end2                                                     204
#
#                                                           S4  \
# wt1                                               SRITLHVDCL
# positions  [205, 206, 207, 208, 209, 210, 211, 212, 213, ...
# len1                                                      10
# len2                                                      10
# start1                                                   205
# end1                                                     214
# wt2                                               SAFKALAVAI
# start2                                                   225
# end2                                                     234
#
#                                                           S5  \
# wt1                                               RGKNDHHRSE
# positions  [215, 216, 217, 218, 219, 220, 221, 222, 223, ...
# len1                                                      10
# len2                                                      11
# start1                                                   215
# end1                                                     224
# wt2                                              REATSPNGTND
# start2                                                   235
# end2                                                     251
#
#                                                           S6  \
# wt1                                               CGIALGQAFK
# positions  [130, 131, 132, 133, 134, 135, 136, 137, 138, ...
# len1                                                      10
# len2                                                      10
# start1                                                   130
# end1                                                     139
# wt2                                               RFGSGFAPLD
# start2                                                   150
# end2                                                     159
#
#                                                           S7  \
# wt1                                               IHALAKHSGW
# positions  [100, 101, 102, 103, 104, 105, 106, 107, 108, ...
# len1                                                      10
# len2                                                      10
# start1                                                   100
# end1                                                     109
# wt2                                               HIDDHHTTED
# start2                                                   120
# end2                                                     129
#
#                                                           S8  \
# wt1                                               HTGIGFLDHM
# positions  [90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 110, ...
# len1                                                      10
# len2                                                      10
# start1                                                    90
# end1                                                      99
# wt2                                               SLIVECIGDL
# start2                                                   110
# end2                                                     119
#
#                                                           S9  \
# wt1                                                   PEKEAE
# positions  [66, 67, 68, 73, 74, 75, 82, 83, 84, 85, 86, 8...
# len1                                                       6
# len2                                                       8
# start1                                                    66
# end1                                                      75
# wt2                                                 TQSQVINV
# start2                                                    82
# end2                                                      89
#
#                                                         S10  \
# wt1                                                  IEHSIF
# positions  [41, 42, 43, 44, 64, 65, 76, 77, 78, 79, 80, 81]
# len1                                                      6
# len2                                                      6
# start1                                                   41
# end1                                                     65
# wt2                                                  AVAEQA
# start2                                                   76
# end2                                                     81
#
#                                                     S11  \
# wt1                                              NETKIQ
# positions  [24, 25, 26, 27, 28, 29, 36, 37, 38, 39, 40]
# len1                                                  6
# len2                                                  5
# start1                                               24
# end1                                                 29
# wt2                                               GGPLA
# start2                                               36
# end2                                                 40
#
#                                                          S12
# wt1                                                  ALVKRIT
# positions  [17, 18, 19, 20, 21, 22, 23, 30, 31, 32, 33, 3...
# len1                                                       7
# len2                                                       6
# start1                                                    17
# end1                                                      23
# wt2                                                   IAISLK
# start2                                                    30
# end2                                                      35

# %%
for chunk in clean_data:
    for ind in range(len(sqs[chunk])):
        sqs[chunk][ind] = sqs[chunk][ind][:int(positions[chunk].ix['len1'])] + sqs[chunk][ind][-int(positions[chunk].ix['len2']):]

# %%
test = pd.DataFrame(columns = sqs['S1'], index = sqs['S1'])

# %%
test
